# %% [markdown]
# This notebook is to check for PDBs containing mutations

# %%
#########################################################################################################################
#################################################    who (P)DB          #################################################
#########################################################################################################################

## file with general functions and variables useful for a lot of MSEAL stuff
import pandas as pd
import numpy as np
import os
import math
pd.set_option('max_colwidth', 100)
pd.set_option('max_rows', 10000)

# %%
DATA_DIR = "/Users/ryan/Desktop/data"
PDB_DIR = "%s/PDBs/" % (DATA_DIR)
PDB_chain_DIR  = "%s/PDB_chains/" % (DATA_DIR)

# %%
#####################################################################
######             CREATE WORKABLE PDB DATAFRAME               ######
#####################################################################


## simple dataframe from pdb (with NMR adjustment)
def get_PDB_DF(pdb, PDB_file=None):
    pdb_id = pdb[:4]
    if PDB_file == None:
        PDB_file = "%s/%s/%s/%s.pdb" %(PDB_DIR, pdb_id[0], pdb_id[1], pdb_id)
    ## downlod pdb file if not already downloaded
    if not(os.path.isfile(PDB_file)):
        os.system("curl https://files.rcsb.org/view/%s.pdb -o %s" %(pdb_id, PDB_file))
        
    f = open(PDB_file, "r")
    pdb_lines = f.readlines()
    pdb_file_df = pd.DataFrame(pdb_lines, columns = ['raw'])
    pdb_file_df['raw'] = pdb_file_df['raw'].str[:80]
    pdb_file_df['key'] = pdb_file_df['raw'].str[:6].str.replace(' ', '')
    ## only keep first model, mostly for NMR models
    pdb_file_df = get_first_model(pdb_file_df)
    return(pdb_file_df)

def get_first_model(PDB_DF):
    MODEL_DF = PDB_DF[PDB_DF['key'] == 'MODEL']
    ## return if NMR does not use multiple models
    if len(MODEL_DF) < 2:
        return(PDB_DF)
    
    ENDMDL_DF = PDB_DF[PDB_DF['key'] == 'ENDMDL']
    ## get range of all non first model coordinate lines
    index_srt_scnd_MDL = MODEL_DF.index.tolist()[1]
    index_end_MDLs = ENDMDL_DF.index.tolist()[len(ENDMDL_DF)-1]
    ## remove all non first model coordinate lines
    newPDB_DF = PDB_DF.loc[:index_srt_scnd_MDL-1]
    newPDB_DF = newPDB_DF.append(PDB_DF.loc[index_end_MDLs+1:])
    newPDB_DF = newPDB_DF.reset_index(drop=True)
    return(newPDB_DF)

# %%
## 'ATOM' and 'HETATM' use get_ATOM_DF for a atom level dataframe
def get_SEQADV_DF(SEQADV):
    SEQADV_data = split_SEQADV(SEQADV['raw'])
    SEQADV = pd.DataFrame({
         'idCode':SEQADV_data[0]  , 'resName':SEQADV_data[1],  'chainID':SEQADV_data[2]     \
        ,'seqNum':SEQADV_data[3]  , 'iCode':SEQADV_data[4]  ,  'database':SEQADV_data[5]     \
        ,'dbIdCode':SEQADV_data[6], 'dbRes':SEQADV_data[7]  ,  'dbSeq':SEQADV_data[8]          \
        ,'conflict':SEQADV_data[9]  })
    return(SEQADV)


def split_SEQADV(raw):
    return(  raw.str[6:11].str.replace(' ', ''),  raw.str[12:15].str.replace(' ', ''),     raw.str[16].str.replace(' ', ''), \
            raw.str[17:22].str.replace(' ', ''),     raw.str[23].str.replace(' ', ''),  raw.str[24:27].str.replace(' ', ''), \
            raw.str[29:37].str.replace(' ', ''),  raw.str[39:42].str.replace(' ', ''),  raw.str[43:48].str.replace(' ', ''), \
            raw.str[49:].str.replace(' ', '') )

def get_mutated_atom_df(pdb, pdb_df):
    atom_df = get_ATOM_DF(pdb_df[pdb_df['key']=="ATOM"], pdb)
    ## need to add unadjusted modified residues 
    more_atom_df = get_ATOM_DF(pdb_df[pdb_df['key']=="HETATM"], pdb)
    atom_df = atom_df.append(more_atom_df)
    
    seqadv_df = get_SEQADV_DF(pdb_df[pdb_df['key']=="SEQADV"])
    
    mutated_atoms_df = [] #pd.DataFrame(columns = atom_df.columns)
    for index, row in seqadv_df.iterrows():
        mutated_atom = atom_df[atom_df['chainID']==row['chainID']].copy()
        mutated_atom = mutated_atom[mutated_atom['seqNum']==row['seqNum']]
        mutated_atom['conflict'] = row['conflict']
        mutated_atoms_df.append(mutated_atom)
    if len(mutated_atoms_df) == 0:
        mutated_atoms_df = pd.DataFrame(columns = atom_df.columns)
    else:
        mutated_atoms_df = pd.concat(mutated_atoms_df, ignore_index=True)
    return(mutated_atoms_df)

# %%
MUTATION_CONFLICTS = ["ENGINEERED", "ENGINEEREDMUTATION", "DELETION", "INSERTION", "CONFLICT"]
def pdb_mutations(pdb_name):
    #print(pdb_name)
    conflicted_pdb = False
    all_conflicts = []
    mutated_pdb=False
    mutated_conflicts = []
    
    pdb=pdb_name[:4]
    pdb_df = get_PDB_DF(pdb)
    seqadv_df = get_SEQADV_DF(pdb_df[pdb_df['key']=="SEQADV"])
    #display(seqadv_df)
    
    if len(seqadv_df) >= 1:
        conflicted_pdb = True
        all_conflicts = seqadv_df['conflict'].unique().tolist()
    
    seqadv_df = seqadv_df.loc[seqadv_df['conflict'].isin(MUTATION_CONFLICTS)]
    if len(seqadv_df) >= 1:
        mutated_pdb = True
        mutated_conflicts = seqadv_df['conflict'].unique().tolist()
        
    
    return(pdb_name, mutated_pdb, mutated_conflicts, conflicted_pdb, all_conflicts)# str(all_conflicts).replace('[',''))

pdb_mutations("5FOK")
# Out:
# ('5FOK', False, [], True, ['EXPRESSIONTAG'])

# %%
membrane_bbarrel_pdbs = pd.read_table("membranBbarrelPDBs.txt",header=None,names=['pdb_name'])
display(membrane_bbarrel_pdbs.head(2))
print(membrane_bbarrel_pdbs.shape)
# Out:
#   pdb_name
# 0     5FOK
# 1     4FSP
# (579, 1)

# %%
mutant_data = []
pdb_list = membrane_bbarrel_pdbs['pdb_name'].unique().tolist()
print(len(pdb_list), ' pdbs')
for pdb in pdb_list:
    
    if 0==(pdb_list.index(pdb)%100):print('\n%s'%(pdb_list.index(pdb)),end='')
    print('.',end='')
    mutant_data.append(pdb_mutations(pdb))
mutant_data = pd.DataFrame(mutant_data, columns=['PDB', 'mutated_pdb', 'mutated_conflicts', 'conflicted_pdb', 'all_conflicts'])
mutant_data['all_conflicts'] = mutant_data['all_conflicts'].astype(str).str.replace('[','').str.replace(']','').str.replace('\'','')
mutant_data['mutated_conflicts'] = mutant_data['mutated_conflicts'].astype(str).str.replace('[','').str.replace(']','').str.replace('\'','')
mutant_data
# Out:
# 579  pdbs
#
# 0....................................................................................................
# 100....................................................................................................
# 200....................................................................................................
# 300....................................................................................................
# 400....................................................................................................
# 500...............................................................................
#       PDB  mutated_pdb              mutated_conflicts  conflicted_pdb  \
# 0    5FOK        False                                           True
# 1    4FSP        False                                           True
# 2    5FQ6        False                                          False
# 3    3PGR         True             ENGINEEREDMUTATION            True
# 4    5MDQ        False                                          False
# 5    2W76         True                       CONFLICT            True
# 6    2VDF         True                       CONFLICT            True
# 7    1MPQ        False                                          False
# 8    6U3T         True                       CONFLICT            True
# 9    3DZM         True                      INSERTION            True
# 10   6DLW        False                                          False
# 11   3SZD        False                                           True
# 12   2LHF        False                                           True
# 13   1BXW         True             ENGINEEREDMUTATION            True
# 14   6RHV         True             ENGINEEREDMUTATION            True
# 15   6ENE        False                                          False
# 16   1PRN        False                                          False
# 17   2W75        False                                          False
# 18   2N6L        False                                           True
# 19   3T0S        False                                           True
# 20   1FW3        False                                           True
# 21   6JNF        False                                           True
# 22   5M9B        False                                           True
# 23   3Q6B        False                                           True
# 24   1OPF        False                                          False
# 25   6RCK        False                                           True
# 26   5FP2        False                                           True
# 27   3M8B        False                                          False
# 28   6UWR        False                                          False
# 29   4B61        False                                          False
# 30   6I2J         True             ENGINEEREDMUTATION            True
# 31   6EHD         True             ENGINEEREDMUTATION            True
# 32   4ZGV        False                                           True
# 33   6BPO        False                                          False
# 34   1P4T        False                                          False
# 35   5ZDH        False                                          False
# 36   1QJ8         True             ENGINEEREDMUTATION            True
# 37   2R4O         True           ENGINEERED, CONFLICT            True
# 38   6UCU        False                                           True
# 39   3J9C        False                                          False
# 40   6AIT        False                                           True
# 41   3M4E         True                     ENGINEERED            True
# 42   6QGW         True                       CONFLICT            True
# 43   2O5P        False                                          False
# 44   5LDV         True             ENGINEEREDMUTATION            True
# 45   6ODJ        False                                          False
# 46   1LKF        False                                          False
# 47   3UU2        False                                          False
# 48   3W9T         True             ENGINEEREDMUTATION            True
# 49   2MAF        False                                          False
# 50   5LJO        False                                          False
# 51   3A2U        False                                          False
# 52   2J4U         True                       CONFLICT            True
# 53   3SYB        False                                           True
# 54   6U49        False                                          False
# 55   2JMM        False                                          False
# 56   1TLY        False                                           True
# 57   3O0E        False                                          False
# 58   3POX        False                                          False
# 59   6SLJ        False                                           True
# 60   5AZO        False                                           True
# 61   6HCG        False                                          False
# 62   3D5K        False                                           True
# 63   2F1V        False                                           True
# 64   6G6U        False                                           True
# 65   4AIQ        False                                           True
# 66   2F1C        False                                           True
# 67   3ANZ        False                                           True
# 68   4MT0        False                                          False
# 69   6S3R        False                                           True
# 70   3V89        False                                           True
# 71   3SLO         True             ENGINEEREDMUTATION            True
# 72   6TIR        False                                           True
# 73   1ILZ        False                                           True
# 74   5G26        False                                          False
# 75   6OKR         True                       CONFLICT            True
# 76   1NQE        False                                          False
# 77   5MDP        False                                           True
# 78   2WJQ        False                                          False
# 79   5MWV        False                                           True
# 80   3T20        False                                           True
# 81   6SML        False                                          False
# 82   2PRN         True             ENGINEEREDMUTATION            True
# 83   2V9H        False                                          False
# 84   2M06        False                                          False
# 85   6FOK        False                                          False
# 86   4D5B        False                                           True
# 87   3Q5M        False                                           True
# 88   1FCP         True                      INSERTION            True
# 89   3WI4        False                                           True
# 90   2ZLD        False                                          False
# 91   6QGX         True             ENGINEEREDMUTATION            True
# 92   1MPR        False                                          False
# 93   6BPN        False                                          False
# 94   3K19        False                                          False
# 95   3SYS        False                                           True
# 96   1QFF        False                                           True
# 97   6LQH        False                                           True
# 98   6GIE        False                                           True
# 99   6DUZ        False                                          False
# 100  2IWV        False                                          False
# 101  4RJW        False                                           True
# 102  6QAM        False                                           True
# 103  3QQ2         True             ENGINEEREDMUTATION            True
# 104  2N2M        False                                          False
# 105  6Q15        False                                          False
# 106  2QK7         True                     ENGINEERED            True
# 107  4E1T         True             ENGINEEREDMUTATION            True
# 108  2Y2X        False                                          False
# 109  2KM7         True                     ENGINEERED            True
# 110  1MAL        False                                          False
# 111  6I96        False                                          False
# 112  5FMW        False                                          False
# 113  4QL0         True             ENGINEEREDMUTATION            True
# 114  5IV8        False                                           True
# 115  2X55        False                                           True
# 116  6BPM        False                                          False
# 117  5NC3        False                                           True
# 118  4N4R        False                                          False
# 119  5MDR        False                                           True
# 120  2W6T        False                                          False
# 121  5TCQ        False                                          False
# 122  3M2L         True                     ENGINEERED            True
# 123  4D64        False                                          False
# 124  4CU4        False                                           True
# 125  1T16        False                                           True
# 126  2W6U        False                                          False
# 127  1MM4        False                                           True
# 128  2GRX        False                                           True
# 129  4I0N        False                                          False
# 130  6H3I        False                                          False
# 131  2R8A         True             DELETION, CONFLICT            True
# 132  1PO0        False                                          False
# 133  5NUO        False                                          False
# 134  3EMO        False                                          False
# 135  6SI7        False                                           True
# 136  4K7K        False                                           True
# 137  5EFR        False                                           True
# 138  2GR7        False                                           True
# 139  5JZT        False                                          False
# 140  6I2L         True             ENGINEEREDMUTATION            True
# 141  3NSJ         True             ENGINEEREDMUTATION            True
# 142  4N75        False                                           True
# 143  1OH2         True   CONFLICT, ENGINEEREDMUTATION            True
# 144  2XE2        False                                          False
# 145  5D0Q        False                                           True
# 146  4FUV        False                                           True
# 147  3C0M         True                     ENGINEERED            True
# 148  5K59        False                                           True
# 149  1CWV        False                                          False
# 150  1I78         True                     ENGINEERED            True
# 151  2QTK        False                                          False
# 152  2GE4         True                     ENGINEERED            True
# 153  4MT4        False                                           True
# 154  5NXR        False                                          False
# 155  5DL7        False                                           True
# 156  1BY5         True                       CONFLICT            True
# 157  5GAQ        False                                           True
# 158  3SY9        False                                           True
# 159  3PGU         True             ENGINEEREDMUTATION            True
# 160  3BS0        False                                           True
# 161  6L7C        False                                          False
# 162  6PSN        False                                          False
# 163  5ONU        False                                           True
# 164  1GFO         True                     ENGINEERED            True
# 165  6CB8        False                                           True
# 166  2X56        False                                          False
# 167  3SLT         True             ENGINEEREDMUTATION            True
# 168  3RBH        False                                           True
# 169  1MPF         True                       CONFLICT            True
# 170  6KLW        False                                           True
# 171  1MPN        False                                          False
# 172  2QOM        False                                           True
# 173  6R1F         True             ENGINEEREDMUTATION            True
# 174  4AZL        False                                          False
# 175  2IWW        False                                          False
# 176  4CTD         True   ENGINEEREDMUTATION, DELETION            True
# 177  1XEZ        False                                          False
# 178  2R4P         True           ENGINEERED, CONFLICT            True
# 179  3DWN         True                     ENGINEERED            True
# 180  5FQ7        False                                          False
# 181  4RDT        False                                           True
# 182  6QWR        False                                           True
# 183  1IM0        False                                           True
# 184  5TCR        False                                          False
# 185  2WJR         True             ENGINEEREDMUTATION            True
# 186  4RVW        False                                           True
# 187  6EHF         True             ENGINEEREDMUTATION            True
# 188  5O79         True                       CONFLICT            True
# 189  5OR1        False                                          False
# 190  3PRW        False                                           True
# 191  5W68        False                                          False
# 192  5T4Y        False                                           True
# 193  5C58         True             ENGINEEREDMUTATION            True
# 194  4FMS        False                                          False
# 195  5LGO        False                                          False
# 196  1H6S        False                                          False
# 197  1HXU         True                     ENGINEERED            True
# 198  6U33        False                                          False
# 199  1NQG        False                                          False
# 200  3OG5        False                                           True
# 201  1ILD         True                     ENGINEERED            True
# 202  4MKO        False                                          False
# 203  4D5D        False                                           True
# 204  5T3R        False                                           True
# 205  4NHR        False                                           True
# 206  5NEC         True                       CONFLICT            True
# 207  3FID        False                                          False
# 208  3SNS        False                                          False
# 209  1YC9         True           ENGINEERED, CONFLICT            True
# 210  1GFP         True                     ENGINEERED            True
# 211  4D5U        False                                          False
# 212  2WMZ         True             ENGINEEREDMUTATION            True
# 213  1K24        False                                          False
# 214  6UZB        False                                          False
# 215  1XKW        False                                          False
# 216  4Q35        False                                           True
# 217  5WAQ        False                                           True
# 218  2XE3        False                                           True
# 219  3LKF        False                                          False
# 220  1MPM        False                                          False
# 221  4FSO        False                                           True
# 222  6EHB        False                                          False
# 223  5NUP         True                       CONFLICT            True
# 224  2IAH        False                                          False
# 225  6U3F        False                                          False
# 226  5ODW        False                                           True
# 227  4LSI        False                                           True
# 228  4XNK        False                                          False
# 229  4AUI         True                       CONFLICT            True
# 230  3VZU        False                                          False
# 231  1QFG        False                                           True
# 232  4Q7G        False                                           True
# 233  4FOZ         True             ENGINEEREDMUTATION            True
# 234  7BRM        False                                          False
# 235  2GR8        False                                           True
# 236  2Y0L        False                                          False
# 237  4UV3        False                                          False
# 238  1NQF         True                     ENGINEERED            True
# 239  3RGN         True             ENGINEEREDMUTATION            True
# 240  5FVN        False                                          False
# 241  2QDZ        False                                          False
# 242  1UYN        False                                          False
# 243  4B7O        False                                           True
# 244  3OHN        False                                           True
# 245  6EHE         True                       CONFLICT            True
# 246  3FYX         True                     ENGINEERED            True
# 247  3BRZ        False                                           True
# 248  5PRN         True                     ENGINEERED            True
# 249  1E54        False                                           True
# 250  2VDE         True   CONFLICT, ENGINEEREDMUTATION            True
# 251  6SLN        False                                           True
# 252  3RGM         True             ENGINEEREDMUTATION            True
# 253  4QKY        False                                          False
# 254  2K4T        False                                           True
# 255  2XMN         True   CONFLICT, ENGINEEREDMUTATION            True
# 256  5FR8        False                                           True
# 257  2GSK        False                                          False
# 258  2W77        False                                          False
# 259  3NJT         True             ENGINEEREDMUTATION            True
# 260  5LDT        False                                          False
# 261  4LSE        False                                           True
# 262  1THQ        False                                           True
# 263  4LSF        False                                           True
# 264  3PGS         True             ENGINEEREDMUTATION            True
# 265  4RLC        False                                           True
# 266  3JTY        False                                           True
# 267  1UUN         True             ENGINEEREDMUTATION            True
# 268  3Q54        False                                          False
# 269  5AZP        False                                           True
# 270  3T24        False                                          False
# 271  3POQ        False                                          False
# 272  4GF4         True             ENGINEEREDMUTATION            True
# 273  5NC4        False                                           True
# 274  3DDR         True                     ENGINEERED            True
# 275  2POR        False                                          False
# 276  4RL8        False                                           True
# 277  2O4V        False                                          False
# 278  2R89         True             DELETION, CONFLICT            True
# 279  6U23        False                                           True
# 280  4MEE         True                       CONFLICT            True
# 281  2YHC         True                       CONFLICT            True
# 282  3PRN         True                     ENGINEERED            True
# 283  2W78        False                                          False
# 284  3AEH         True                     ENGINEERED            True
# 285  4EPA        False                                           True
# 286  5O9C        False                                          False
# 287  3X2R        False                                          False
# 288  4K3C        False                                          False
# 289  3RFZ        False                                           True
# 290  1MPO        False                                          False
# 291  5OYK         True                       CONFLICT            True
# 292  6F2E        False                                          False
# 293  1KMP        False                                          False
# 294  1NQH        False                                          False
# 295  5AZS        False                                           True
# 296  1Q9F         True                     ENGINEERED            True
# 297  5WLN        False                                          False
# 298  6UZE        False                                          False
# 299  6HCP        False                                           True
# 300  4Y25        False                                           True
# 301  2FCP         True                      INSERTION            True
# 302  2ZFG        False                                          False
# 303  1FW2        False                                           True
# 304  2YH5        False                                           True
# 305  2BEG        False                                          False
# 306  4XNL        False                                          False
# 307  2MHL        False                                           True
# 308  2Y0H        False                                          False
# 309  6G73        False                                           True
# 310  7AHL        False                                          False
# 311  1OSM        False                                          False
# 312  1QKC         True                      INSERTION            True
# 313  2MPR        False                                          False
# 314  6KZ3        False                                          False
# 315  5NXU        False                                          False
# 316  4P1X         True             ENGINEEREDMUTATION            True
# 317  4K7R        False                                           True
# 318  6TZK        False                                           True
# 319  2YH3         True                       CONFLICT            True
# 320  6N38        False                                           True
# 321  6UCV        False                                           True
# 322  6T1W        False                                          False
# 323  1UJW        False                                          False
# 324  5D0O        False                                           True
# 325  6RWK        False                                          False
# 326  5O78        False                                          False
# 327  5XDO        False                                           True
# 328  3HW9        False                                          False
# 329  5AYW        False                                           True
# 330  2FGQ        False                                          False
# 331  6I98        False                                          False
# 332  6O2N        False                                          False
# 333  4E1S        False                                          False
# 334  5WC3        False                                           True
# 335  2W16        False                                          False
# 336  3M4D         True                     ENGINEERED            True
# 337  5IMW         True                       CONFLICT            True
# 338  6EHC        False                                          False
# 339  3BRY        False                                           True
# 340  2LME        False                                           True
# 341  5IUY        False                                           True
# 342  1WXR        False                                          False
# 343  3UPG         True                       DELETION            True
# 344  3SZV        False                                           True
# 345  6UMM        False                                          False
# 346  3QLB        False                                           True
# 347  6OFR        False                                          False
# 348  2X8X         True                       CONFLICT            True
# 349  5EC5         True             ENGINEEREDMUTATION            True
# 350  5NUR        False                                          False
# 351  5OUT         True             ENGINEEREDMUTATION            True
# 352  2R4L         True           ENGINEERED, CONFLICT            True
# 353  3POR        False                                          False
# 354  6FOM         True             ENGINEEREDMUTATION            True
# 355  2YNK        False                                          False
# 356  1ORM         True                     ENGINEERED            True
# 357  4J3O         True                       CONFLICT            True
# 358  3K1B        False                                          False
# 359  5EKQ        False                                          False
# 360  2VDD         True   CONFLICT, ENGINEEREDMUTATION            True
# 361  4HSC        False                                          False
# 362  5MZS         True             ENGINEEREDMUTATION            True
# 363  2QCZ        False                                           True
# 364  6CD2        False                                           True
# 365  2HDI         True                     ENGINEERED            True
# 366  6RCP        False                                           True
# 367  6L7A        False                                          False
# 368  5NR2        False                                           True
# 369  6TIQ        False                                           True
# 370  6Q5E        False                                          False
# 371  4TW1        False                                           True
# 372  8PRN         True                     ENGINEERED            True
# 373  5JDP         True                       CONFLICT            True
# 374  2XE1        False                                          False
# 375  5FP1        False                                           True
# 376  6U3Y        False                                          False
# 377  3VY8        False                                          False
# 378  6I1Y         True                       CONFLICT            True
# 379  2JK4        False                                          False
# 380  2OMF        False                                          False
# 381  1FEP        False                                           True
# 382  3CSL        False                                           True
# 383  4Q79        False                                          False
# 384  4BUM        False                                           True
# 385  2D1U        False                                           True
# 386  6H3J         True                       CONFLICT            True
# 387  4RLB        False                                           True
# 388  1PO3        False                                          False
# 389  3KWV         True           ENGINEERED, DELETION            True
# 390  3JQO        False                                           True
# 391  4P24         True             ENGINEEREDMUTATION            True
# 392  1KMO        False                                          False
# 393  3ML3        False                                           True
# 394  4PR7        False                                           True
# 395  4GCS        False                                           True
# 396  3QRC        False                                           True
# 397  5WAM        False                                           True
# 398  1BY3         True                       CONFLICT            True
# 399  2N2L        False                                          False
# 400  1GFQ         True                     ENGINEERED            True
# 401  3HWB        False                                          False
# 402  5WQ8        False                                          False
# 403  5WQ7        False                                          False
# 404  2YSU        False                                          False
# 405  5XDN        False                                           True
# 406  4KR4        False                                          False
# 407  4RDR        False                                           True
# 408  3Q7M        False                                           True
# 409  4AIP         True                       CONFLICT            True
# 410  3NSG        False                                          False
# 411  3B07        False                                           True
# 412  1GFM         True                     ENGINEERED            True
# 413  5MDO        False                                           True
# 414  2MLH        False                                          False
# 415  5FQ8        False                                          False
# 416  4LSH        False                                           True
# 417  5DL5        False                                           True
# 418  4RHB        False                                           True
# 419  3VZT        False                                          False
# 420  5D5D        False                                          False
# 421  5LY6         True                       CONFLICT            True
# 422  4FQE        False                                           True
# 423  1G90         True                     ENGINEERED            True
# 424  6FSU         True                       CONFLICT            True
# 425  5DL8        False                                           True
# 426  2WVP         True             ENGINEEREDMUTATION            True
# 427  4C4V         True                       CONFLICT            True
# 428  2ODJ        False                                           True
# 429  3FHH        False                                          False
# 430  2VQI        False                                          False
# 431  3EMN        False                                           True
# 432  5O65         True             ENGINEEREDMUTATION            True
# 433  2XG6        False                                           True
# 434  5O8O        False                                          False
# 435  6R2Q         True                       CONFLICT            True
# 436  3O44         True                       CONFLICT            True
# 437  3VY9        False                                          False
# 438  1TLW        False                                           True
# 439  4K3B        False                                          False
# 440  2R88         True                       CONFLICT            True
# 441  1XKH        False                                          False
# 442  6RB9        False                                           True
# 443  3POU        False                                          False
# 444  2LAF        False                                           True
# 445  5IMY         True                       CONFLICT            True
# 446  6O2O        False                                          False
# 447  2K0L        False                                           True
# 448  4V3G        False                                           True
# 449  4DCB         True  ENGINEEREDMUTATION, INSERTION            True
# 450  2JQY        False                                          False
# 451  2IXW        False                                          False
# 452  5O68         True   ENGINEEREDMUTATION, CONFLICT            True
# 453  1T1L        False                                           True
# 454  5BUN        False                                          False
# 455  4AFK        False                                          False
# 456  3CSN        False                                           True
# 457  3DWO        False                                           True
# 458  1FI1        False                                           True
# 459  6S3S        False                                           True
# 460  4RL9        False                                           True
# 461  4C00        False                                           True
# 462  1TQQ        False                                          False
# 463  6V78        False                                           True
# 464  2R4N         True           ENGINEERED, CONFLICT            True
# 465  4JFB        False                                          False
# 466  2GUF        False                                          False
# 467  7PRN         True                     ENGINEERED            True
# 468  4D51        False                                          False
# 469  5VJ8        False                                          False
# 470  1EK9        False                                           True
# 471  6OQH         True             DELETION, CONFLICT            True
# 472  3SZE         True             ENGINEEREDMUTATION            True
# 473  1F02        False                                           True
# 474  5IXM        False                                           True
# 475  6UZD        False                                          False
# 476  4FT6        False                                           True
# 477  4P1Y         True             ENGINEEREDMUTATION            True
# 478  3V8X         True             ENGINEEREDMUTATION            True
# 479  6EUS         True                       CONFLICT            True
# 480  1HXX         True                     ENGINEERED            True
# 481  3SY7        False                                           True
# 482  1TLZ        False                                           True
# 483  6V05         True             ENGINEEREDMUTATION            True
# 484  1QJQ         True                      INSERTION            True
# 485  5DQX        False                                          False
# 486  1PVL         True                       CONFLICT            True
# 487  3QKY        False                                           True
# 488  5NXN         True             DELETION, CONFLICT            True
# 489  4XGA        False                                          False
# 490  1QD5        False                                          False
# 491  6E14         True                       CONFLICT            True
# 492  1A0T        False                                          False
# 493  1A0S        False                                          False
# 494  2X4M         True             ENGINEEREDMUTATION            True
# 495  6U2S        False                                          False
# 496  4FRX        False                                           True
# 497  3EFC        False                                           True
# 498  5B5R        False                                           True
# 499  2Y0K        False                                           True
# 500  6I97        False                                          False
# 501  6RD3        False                                           True
# 502  2X27        False                                           True
# 503  6PRN         True                     ENGINEERED            True
# 504  3A2S        False                                          False
# 505  3SLJ         True             ENGINEEREDMUTATION            True
# 506  2MNH         True                       CONFLICT            True
# 507  6WUH        False                                          False
# 508  2J1N        False                                          False
# 509  1UYO        False                                          False
# 510  3KVN        False                                           True
# 511  3EFM        False                                           True
# 512  1QJP         True             ENGINEEREDMUTATION            True
# 513  1AF6        False                                          False
# 514  4KRA        False                                          False
# 515  1GFN         True                       DELETION            True
# 516  4D65        False                                          False
# 517  6U4P         True             ENGINEEREDMUTATION            True
# 518  5O67         True   ENGINEEREDMUTATION, CONFLICT            True
# 519  5IYU        False                                          False
# 520  4FRT        False                                           True
# 521  2XE5        False                                           True
# 522  4C69        False                                           True
# 523  2IXX        False                                          False
# 524  1BH3         True                     ENGINEERED            True
# 525  1PHO        False                                          False
# 526  6DV3        False                                          False
# 527  6SJL        False                                          False
# 528  2HDF         True                     ENGINEERED            True
# 529  6OKU        False                                          False
# 530  4GEY         True             ENGINEEREDMUTATION            True
# 531  1MM5        False                                           True
# 532  6H7F        False                                           True
# 533  1QD6        False                                          False
# 534  3M8D        False                                          False
# 535  4MJT        False                                          False
# 536  3TGO        False                                           True
# 537  5O77        False                                          False
# 538  6V0C        False                                          False
# 539  6V81        False                                          False
# 540  6E15         True                       CONFLICT            True
# 541  6CXO         True             ENGINEEREDMUTATION            True
# 542  3P1L        False                                           True
# 543  4Y1K        False                                           True
# 544  1BT9         True                     ENGINEERED            True
# 545  3PIK        False                                           True
# 546  2FGR        False                                           True
# 547  1PNZ        False                                          False
# 548  3PF1         True             ENGINEEREDMUTATION            True
# 549  4V3H        False                                           True
# 550  3MC9        False                                           True
# 551  2YH9        False                                           True
# 552  3FIP        False                                           True
# 553  1HXT         True                     ENGINEERED            True
# 554  1PFO         True                       CONFLICT            True
# 555  6H03        False                                          False
# 556  6I1X         True                       CONFLICT            True
# 557  6E4V        False                                          False
# 558  6QGY         True             ENGINEEREDMUTATION            True
# 559  6KLX        False                                          False
# 560  1WP1        False                                           True
# 561  5IVA        False                                           True
# 562  6SGW        False                                          False
# 563  1QJ9         True             ENGINEEREDMUTATION            True
# 564  2ERV        False                                          False
# 565  2X9K         True             ENGINEEREDMUTATION            True
# 566  5MDS        False                                          False
# 567  2YH6        False                                          False
# 568  3VZW        False                                          False
# 569  3QRA        False                                           True
# 570  5IV9        False                                          False
# 571  4GCQ        False                                           True
# 572  3WI5         True             ENGINEEREDMUTATION            True
# 573  2F1T        False                                           True
# 574  3GP6        False                                           True
# 575  4RAP         True             ENGINEEREDMUTATION            True
# 576  4H56        False                                           True
# 577  5DL6        False                                           True
# 578  5NUQ        False                                          False
#
#                                                all_conflicts
# 0                                              EXPRESSIONTAG
# 1                                              EXPRESSIONTAG
# 2
# 3                          ENGINEEREDMUTATION, EXPRESSIONTAG
# 4
# 5                                                   CONFLICT
# 6                                                   CONFLICT
# 7
# 8                                                   CONFLICT
# 9                                                  INSERTION
# 10
# 11                                             EXPRESSIONTAG
# 12                                             EXPRESSIONTAG
# 13                          SEEREMARK999, ENGINEEREDMUTATION
# 14                                        ENGINEEREDMUTATION
# 15
# 16
# 17
# 18                       INITIATINGMETHIONINE, EXPRESSIONTAG
# 19                                             EXPRESSIONTAG
# 20                      N-TERMINALEXTENSION, MODIFIEDRESIDUE
# 21                                             EXPRESSIONTAG
# 22                                             EXPRESSIONTAG
# 23                                             EXPRESSIONTAG
# 24
# 25                                             EXPRESSIONTAG
# 26                                             EXPRESSIONTAG
# 27
# 28
# 29
# 30                                        ENGINEEREDMUTATION
# 31                                        ENGINEEREDMUTATION
# 32                       INITIATINGMETHIONINE, EXPRESSIONTAG
# 33
# 34
# 35
# 36                                        ENGINEEREDMUTATION
# 37                       ENGINEERED, CONFLICT, EXPRESSIONTAG
# 38                                             EXPRESSIONTAG
# 39
# 40                                        SEESEQUENCEDETAILS
# 41                                                ENGINEERED
# 42             INITIATINGMETHIONINE, EXPRESSIONTAG, CONFLICT
# 43
# 44                         EXPRESSIONTAG, ENGINEEREDMUTATION
# 45
# 46
# 47
# 48                         EXPRESSIONTAG, ENGINEEREDMUTATION
# 49
# 50
# 51
# 52                                                  CONFLICT
# 53                                             EXPRESSIONTAG
# 54
# 55
# 56                                             EXPRESSIONTAG
# 57
# 58
# 59                                             EXPRESSIONTAG
# 60                                             EXPRESSIONTAG
# 61
# 62                                             EXPRESSIONTAG
# 63                                             EXPRESSIONTAG
# 64                                             EXPRESSIONTAG
# 65                                    EXPRESSIONTAG, VARIANT
# 66                                             EXPRESSIONTAG
# 67                                             EXPRESSIONTAG
# 68
# 69                                             EXPRESSIONTAG
# 70                                    EXPRESSIONTAG, VARIANT
# 71                         EXPRESSIONTAG, ENGINEEREDMUTATION
# 72                                             EXPRESSIONTAG
# 73                                       N-TERMINALEXTENSION
# 74
# 75                                                  CONFLICT
# 76
# 77                       INITIATINGMETHIONINE, EXPRESSIONTAG
# 78
# ...
# 325
# 326
# 327                                            EXPRESSIONTAG
# 328
# 329                                            EXPRESSIONTAG
# 330
# 331
# 332
# 333
# 334                                            EXPRESSIONTAG
# 335
# 336                                               ENGINEERED
# 337                                                 CONFLICT
# 338
# 339                                            EXPRESSIONTAG
# 340                                            EXPRESSIONTAG
# 341                                            EXPRESSIONTAG
# 342
# 343                                                 DELETION
# 344                                            EXPRESSIONTAG
# 345
# 346                                             SEEREMARK999
# 347
# 348                                                 CONFLICT
# 349                        EXPRESSIONTAG, ENGINEEREDMUTATION
# 350
# 351                                       ENGINEEREDMUTATION
# 352                      ENGINEERED, CONFLICT, EXPRESSIONTAG
# 353
# 354                                       ENGINEEREDMUTATION
# 355
# 356                                               ENGINEERED
# 357                                  EXPRESSIONTAG, CONFLICT
# 358
# 359
# 360                             CONFLICT, ENGINEEREDMUTATION
# 361
# 362                        EXPRESSIONTAG, ENGINEEREDMUTATION
# 363                                          CLONINGARTIFACT
# 364                                            EXPRESSIONTAG
# 365               CLONINGARTIFACT, ENGINEERED, EXPRESSIONTAG
# 366                                            EXPRESSIONTAG
# 367
# 368                                            EXPRESSIONTAG
# 369                                            EXPRESSIONTAG
# 370
# 371                                            EXPRESSIONTAG
# 372                                               ENGINEERED
# 373                                  EXPRESSIONTAG, CONFLICT
# 374
# 375                                            EXPRESSIONTAG
# 376
# 377
# 378                                                 CONFLICT
# 379
# 380
# 381                                          MODIFIEDRESIDUE
# 382                              SEEREMARK999, EXPRESSIONTAG
# 383
# 384                                            EXPRESSIONTAG
# 385                                            EXPRESSIONTAG
# 386                                                 CONFLICT
# 387                                            EXPRESSIONTAG
# 388
# 389                                     ENGINEERED, DELETION
# 390                                             SEEREMARK999
# 391  INITIATINGMETHIONINE, ENGINEEREDMUTATION, EXPRESSIONTAG
# 392
# 393                              EXPRESSIONTAG, SEEREMARK999
# 394                                            EXPRESSIONTAG
# 395                                            EXPRESSIONTAG
# 396                                     INITIATINGMETHIONINE
# 397                                            EXPRESSIONTAG
# 398                                                 CONFLICT
# 399
# 400                                               ENGINEERED
# 401
# 402
# 403
# 404
# 405                                            EXPRESSIONTAG
# 406
# 407                                            EXPRESSIONTAG
# 408                                            EXPRESSIONTAG
# 409                                  EXPRESSIONTAG, CONFLICT
# 410
# 411                                            EXPRESSIONTAG
# 412                                               ENGINEERED
# 413                      INITIATINGMETHIONINE, EXPRESSIONTAG
# 414
# 415
# 416                                            EXPRESSIONTAG
# 417                                            EXPRESSIONTAG
# 418                                            EXPRESSIONTAG
# 419
# 420
# 421                                                 CONFLICT
# 422                                            EXPRESSIONTAG
# 423                                               ENGINEERED
# 424            INITIATINGMETHIONINE, EXPRESSIONTAG, CONFLICT
# 425                                            EXPRESSIONTAG
# 426                        EXPRESSIONTAG, ENGINEEREDMUTATION
# 427                                                 CONFLICT
# 428                           EXPRESSIONTAG, MODIFIEDRESIDUE
# 429
# 430
# 431                                            EXPRESSIONTAG
# 432                        EXPRESSIONTAG, ENGINEEREDMUTATION
# 433                                             SEEREMARK999
# 434
# 435                                                 CONFLICT
# 436                                                 CONFLICT
# 437
# 438                                            EXPRESSIONTAG
# 439
# 440                    SEEREMARK999, CONFLICT, EXPRESSIONTAG
# 441
# 442                      INITIATINGMETHIONINE, EXPRESSIONTAG
# 443
# 444                                            EXPRESSIONTAG
# 445            EXPRESSIONTAG, CONFLICT, INITIATINGMETHIONINE
# 446
# 447                                            EXPRESSIONTAG
# 448                                            EXPRESSIONTAG
# 449             ENGINEEREDMUTATION, EXPRESSIONTAG, INSERTION
# 450
# 451
# 452              EXPRESSIONTAG, ENGINEEREDMUTATION, CONFLICT
# 453                                            EXPRESSIONTAG
# 454
# 455
# 456                              SEEREMARK999, EXPRESSIONTAG
# 457                                            EXPRESSIONTAG
# 458                                         INTRACHAINHISTAG
# 459                                            EXPRESSIONTAG
# 460                                            EXPRESSIONTAG
# 461                                            EXPRESSIONTAG
# 462
# 463                                            EXPRESSIONTAG
# 464                      ENGINEERED, CONFLICT, EXPRESSIONTAG
# 465
# 466
# 467                                               ENGINEERED
# 468
# 469
# 470                                          MODIFIEDRESIDUE
# 471                                       DELETION, CONFLICT
# 472                                       ENGINEEREDMUTATION
# 473                                          CLONINGARTIFACT
# 474                      INITIATINGMETHIONINE, EXPRESSIONTAG
# 475
# 476                                            EXPRESSIONTAG
# 477                        EXPRESSIONTAG, ENGINEEREDMUTATION
# 478               EXPRESSIONTAG, VARIANT, ENGINEEREDMUTATION
# 479                                  EXPRESSIONTAG, CONFLICT
# 480                                               ENGINEERED
# 481                              SEEREMARK999, EXPRESSIONTAG
# 482                                            EXPRESSIONTAG
# 483                ENGINEEREDMUTATION, EXPRESSIONTAG, LINKER
# 484                                                INSERTION
# 485
# 486                                                 CONFLICT
# 487                                            EXPRESSIONTAG
# 488                                       DELETION, CONFLICT
# 489
# 490
# 491            CONFLICT, EXPRESSIONTAG, INITIATINGMETHIONINE
# 492
# 493
# 494                        ENGINEEREDMUTATION, EXPRESSIONTAG
# 495
# 496                                            EXPRESSIONTAG
# 497                                            EXPRESSIONTAG
# 498                                            EXPRESSIONTAG
# 499                                            EXPRESSIONTAG
# 500
# 501                                            EXPRESSIONTAG
# 502                                            EXPRESSIONTAG
# 503                                               ENGINEERED
# 504
# 505                        EXPRESSIONTAG, ENGINEEREDMUTATION
# 506                                                 CONFLICT
# 507
# 508
# 509
# 510                                            EXPRESSIONTAG
# 511                                            EXPRESSIONTAG
# 512                                       ENGINEEREDMUTATION
# 513
# 514
# 515                                                 DELETION
# 516
# 517                                       ENGINEEREDMUTATION
# 518              EXPRESSIONTAG, ENGINEEREDMUTATION, CONFLICT
# 519
# 520                                            EXPRESSIONTAG
# 521                                             SEEREMARK999
# 522                                            EXPRESSIONTAG
# 523
# 524                                               ENGINEERED
# 525
# 526
# 527
# 528             CLONINGARTIFACT, MODIFIEDRESIDUE, ENGINEERED
# 529
# 530                        EXPRESSIONTAG, ENGINEEREDMUTATION
# 531                                            EXPRESSIONTAG
# 532                                            EXPRESSIONTAG
# 533
# 534
# 535
# 536                                            EXPRESSIONTAG
# 537
# 538
# 539
# 540            CONFLICT, EXPRESSIONTAG, INITIATINGMETHIONINE
# 541                        EXPRESSIONTAG, ENGINEEREDMUTATION
# 542                                            EXPRESSIONTAG
# 543                                            EXPRESSIONTAG
# 544                                               ENGINEERED
# 545                                            EXPRESSIONTAG
# 546                                             SEEREMARK999
# 547
# 548                        ENGINEEREDMUTATION, EXPRESSIONTAG
# 549                                            EXPRESSIONTAG
# 550                                            EXPRESSIONTAG
# 551                                            EXPRESSIONTAG
# 552                                            EXPRESSIONTAG
# 553                                               ENGINEERED
# 554                                                 CONFLICT
# 555
# 556                                                 CONFLICT
# 557
# 558  INITIATINGMETHIONINE, EXPRESSIONTAG, ENGINEEREDMUTATION
# 559
# 560                                            EXPRESSIONTAG
# 561                      INITIATINGMETHIONINE, EXPRESSIONTAG
# 562
# 563                                       ENGINEEREDMUTATION
# 564
# 565                                       ENGINEEREDMUTATION
# 566
# 567
# 568
# 569                                     INITIATINGMETHIONINE
# 570
# 571                                            EXPRESSIONTAG
# 572                                       ENGINEEREDMUTATION
# 573                                            EXPRESSIONTAG
# 574                      INITIATINGMETHIONINE, EXPRESSIONTAG
# 575                                       ENGINEEREDMUTATION
# 576                                            EXPRESSIONTAG
# 577                                            EXPRESSIONTAG
# 578

# %%
mutant_data.to_csv("MembaneBbarrelMutationData.csv", index=False)

# %%
soluble_bbarrel_pdbs = pd.read_table("SolubleBbarrelPDBs.txt",header=None,names=['pdb_name'])
soluble_bbarrel_pdbs['pdb_name'] = soluble_bbarrel_pdbs['pdb_name'].str.upper()
display(soluble_bbarrel_pdbs.head(2))
print(soluble_bbarrel_pdbs.shape)
# Out:
#   pdb_name
# 0     2B97
# 1     1R2M
# (1464, 1)

# %%
soluble_bbarrel_pdbs = pd.read_table("SolubleBbarrelPDBs.txt",header=None,names=['pdb_name'])
soluble_bbarrel_pdbs['pdb_name'] = soluble_bbarrel_pdbs['pdb_name'].str.upper()
display(soluble_bbarrel_pdbs.head(2))
print(soluble_bbarrel_pdbs.shape)

soluble_mutant_data = []
pdb_list = soluble_bbarrel_pdbs['pdb_name'].unique().tolist()
print(len(pdb_list), ' pdbs')
for pdb in pdb_list:
    if 0==(pdb_list.index(pdb)%100):print('\n%s'%(pdb_list.index(pdb)),end='')
    print('.',end='')
    soluble_mutant_data.append(pdb_mutations(pdb))
    
soluble_mutant_data = pd.DataFrame(soluble_mutant_data, columns=['PDB', 'mutated_pdb', 'mutated_conflicts', 'conflicted_pdb', 'all_conflicts'])
soluble_mutant_data['all_conflicts'] = soluble_mutant_data['all_conflicts'].astype(str).str.replace('[','').str.replace(']','').str.replace('\'','')
soluble_mutant_data['mutated_conflicts'] = soluble_mutant_data['mutated_conflicts'].astype(str).str.replace('[','').str.replace(']','').str.replace('\'','')
display(soluble_mutant_data.head(10))
print(soluble_mutant_data.shape)
# Out:
#   pdb_name
# 0     2B97
# 1     1R2M
# (1464, 1)
# 1464  pdbs
#
# 0....................................................................................................
# 100....................................................................................................
# 200....................................................................................................
# 300....................................................................................................
# 400....................................................................................................
# 500....................................................................................................
# 600....................................................................................................
# 700....................................................................................................
# 800....................................................................................................
# 900....................................................................................................
# 1000....................................................................................................
# 1100....................................................................................................
# 1200....................................................................................................
# 1300....................................................................................................
# 1400................................................................
#     PDB  mutated_pdb mutated_conflicts  conflicted_pdb    all_conflicts
# 0  2B97        False                             False
# 1  1R2M        False                             False
# 2  2PL7        False                             False
# 3  3QQT        False                             False
# 4  2PL6        False                             False
# 5  2GVM        False                             False
# 6  2FZ6        False                             False
# 7  4BWH        False                              True    EXPRESSIONTAG
# 8  4AOG        False                              True  CLONINGARTIFACT
# 9  1ZVC        False                              True  CLONINGARTIFACT
# (1464, 5)

# %%
soluble_mutant_data.to_csv("SolubleBbarrelMutationData.csv", index=False)
